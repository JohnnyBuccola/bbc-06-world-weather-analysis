# %%
import requests

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lats_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 623

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | magadan
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | sola
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | gilbues
# Processing Record 8 of Set 1 | vila franca do campo
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | mount gambier
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | nemuro
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | kahului
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | ratnagiri
# Processing Record 17 of Set 1 | khor
# Processing Record 18 of Set 1 | yatou
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | hami
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | vao
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | port macquarie
# Processing Record 32 of Set 1 | guiratinga
# Processing Record 33 of Set 1 | khasan
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | colwyn bay
# Processing Record 37 of Set 1 | shelburne
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | whitianga
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | yanam
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | sobolevo
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | villa carlos paz
# Processing Record 4 of Set 2 | taree
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | tahta
# Processing Record 7 of Set 2 | alikalia
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | ostrovnoy
# Processing Record 10 of Set 2 | tumaco
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | varkkallai
# Processing Record 13 of Set 2 | mizan teferi
# Processing Record 14 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 2 | apen
# Processing Record 16 of Set 2 | chara
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | coria
# Processing Record 21 of Set 2 | tezu
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | waingapu
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | muros
# Processing Record 28 of Set 2 | hirara
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | busselton
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | minas de barroteran
# Processing Record 36 of Set 2 | husavik
# Processing Record 37 of Set 2 | sol-iletsk
# Processing Record 38 of Set 2 | san andres
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | kyren
# Processing Record 41 of Set 2 | emba
# Processing Record 42 of Set 2 | karratha
# Processing Record 43 of Set 2 | kaeo
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | pangody
# Processing Record 47 of Set 2 | sawakin
# Processing Record 48 of Set 2 | shellbrook
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 3 | byron bay
# Processing Record 2 of Set 3 | menongue
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | kerchevskiy
# Processing Record 5 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 3 | dunedin
# Processing Record 7 of Set 3 | kaputa
# Processing Record 8 of Set 3 | lerwick
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | nizhnevartovsk
# Processing Record 11 of Set 3 | stephenville
# Processing Record 12 of Set 3 | manali
# Processing Record 13 of Set 3 | teya
# Processing Record 14 of Set 3 | pinotepa nacional
# Processing Record 15 of Set 3 | meulaboh
# Processing Record 16 of Set 3 | buriti bravo
# Processing Record 17 of Set 3 | qarqin
# Processing Record 18 of Set 3 | khani
# Processing Record 19 of Set 3 | basco
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | mayo
# Processing Record 22 of Set 3 | faya
# Processing Record 23 of Set 3 | zhuhai
# Processing Record 24 of Set 3 | guerrero negro
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | bitkine
# Processing Record 27 of Set 3 | kimbe
# Processing Record 28 of Set 3 | copiapo
# Processing Record 29 of Set 3 | oriximina
# Processing Record 30 of Set 3 | pampas
# Processing Record 31 of Set 3 | namatanai
# Processing Record 32 of Set 3 | simao
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | dharchula
# Processing Record 36 of Set 3 | sisimiut
# Processing Record 37 of Set 3 | jumla
# Processing Record 38 of Set 3 | lompoc
# Processing Record 39 of Set 3 | hamilton
# Processing Record 40 of Set 3 | port hawkesbury
# Processing Record 41 of Set 3 | hermanus
# Processing Record 42 of Set 3 | kodino
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | lazaro cardenas
# Processing Record 45 of Set 3 | hurghada
# Processing Record 46 of Set 3 | bull savanna
# Processing Record 47 of Set 3 | roma
# Processing Record 48 of Set 3 | fasa
# Processing Record 49 of Set 3 | yulara
# Processing Record 50 of Set 3 | casper
# Processing Record 1 of Set 4 | roebourne
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | sitio novo do tocantins
# Processing Record 4 of Set 4 | east london
# Processing Record 5 of Set 4 | klaksvik
# Processing Record 6 of Set 4 | moranbah
# Processing Record 7 of Set 4 | general roca
# Processing Record 8 of Set 4 | dubbo
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | eyl
# Processing Record 11 of Set 4 | geraldton
# Processing Record 12 of Set 4 | partenit
# Processing Record 13 of Set 4 | ust-maya
# Processing Record 14 of Set 4 | mweka
# Processing Record 15 of Set 4 | ornskoldsvik
# Processing Record 16 of Set 4 | kavieng
# Processing Record 17 of Set 4 | wenchi
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | glendive
# Processing Record 20 of Set 4 | jasidih
# Processing Record 21 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 4 | tadine
# Processing Record 23 of Set 4 | rancho palos verdes
# Processing Record 24 of Set 4 | tucumcari
# Processing Record 25 of Set 4 | coquimbo
# Processing Record 26 of Set 4 | vogan
# Processing Record 27 of Set 4 | nuuk
# Processing Record 28 of Set 4 | kosh-agach
# Processing Record 29 of Set 4 | saint anthony
# Processing Record 30 of Set 4 | pacific grove
# Processing Record 31 of Set 4 | ancud
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | bathsheba
# Processing Record 34 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 4 | vila velha
# Processing Record 36 of Set 4 | seoul
# Processing Record 37 of Set 4 | putnok
# Processing Record 38 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 4 | saskylakh
# Processing Record 40 of Set 4 | tayibe
# City not found. Skipping...
# Processing Record 41 of Set 4 | dinsor
# City not found. Skipping...
# Processing Record 42 of Set 4 | serik
# Processing Record 43 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 4 | lae
# Processing Record 45 of Set 4 | puerto escondido
# Processing Record 46 of Set 4 | basoko
# Processing Record 47 of Set 4 | santa catalina
# Processing Record 48 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 4 | katherine
# Processing Record 50 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 5 | dongkan
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 5 | risch
# Processing Record 6 of Set 5 | semey
# Processing Record 7 of Set 5 | torit
# Processing Record 8 of Set 5 | mineral wells
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 10 of Set 5 | kodiak
# Processing Record 11 of Set 5 | saint george
# Processing Record 12 of Set 5 | beloha
# Processing Record 13 of Set 5 | port hardy
# Processing Record 14 of Set 5 | haimen
# Processing Record 15 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 16 of Set 5 | fort nelson
# Processing Record 17 of Set 5 | hasaki
# Processing Record 18 of Set 5 | coihaique
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | myitkyina
# Processing Record 21 of Set 5 | abbeville
# Processing Record 22 of Set 5 | paamiut
# Processing Record 23 of Set 5 | huilong
# Processing Record 24 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 25 of Set 5 | sokolo
# Processing Record 26 of Set 5 | asbury park
# Processing Record 27 of Set 5 | kungurtug
# Processing Record 28 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 5 | gostyn
# Processing Record 30 of Set 5 | mbanza-ngungu
# Processing Record 31 of Set 5 | beringovskiy
# Processing Record 32 of Set 5 | terra santa
# Processing Record 33 of Set 5 | aosta
# Processing Record 34 of Set 5 | kalakamati
# Processing Record 35 of Set 5 | naze
# Processing Record 36 of Set 5 | bol
# Processing Record 37 of Set 5 | alofi
# Processing Record 38 of Set 5 | bethel
# Processing Record 39 of Set 5 | cabedelo
# Processing Record 40 of Set 5 | chesma
# Processing Record 41 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 5 | ribnitz-damgarten
# Processing Record 43 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 44 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 5 | laguna
# Processing Record 46 of Set 5 | kuching
# Processing Record 47 of Set 5 | riyadh
# Processing Record 48 of Set 5 | asarganj
# Processing Record 49 of Set 5 | salalah
# Processing Record 50 of Set 5 | pokrovsk
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | zhigansk
# Processing Record 3 of Set 6 | port lincoln
# Processing Record 4 of Set 6 | broken hill
# Processing Record 5 of Set 6 | asau
# Processing Record 6 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 6 | cayenne
# Processing Record 8 of Set 6 | quatre cocos
# Processing Record 9 of Set 6 | adre
# Processing Record 10 of Set 6 | nikolskoye
# Processing Record 11 of Set 6 | port hedland
# Processing Record 12 of Set 6 | saint-joseph
# Processing Record 13 of Set 6 | jimma
# Processing Record 14 of Set 6 | sao joao da barra
# Processing Record 15 of Set 6 | severo-kurilsk
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | trinidad
# Processing Record 18 of Set 6 | fare
# Processing Record 19 of Set 6 | rawlins
# Processing Record 20 of Set 6 | asnaes
# Processing Record 21 of Set 6 | viry-chatillon
# Processing Record 22 of Set 6 | mitsamiouli
# Processing Record 23 of Set 6 | olinda
# Processing Record 24 of Set 6 | shenjiamen
# Processing Record 25 of Set 6 | rawson
# Processing Record 26 of Set 6 | alyangula
# Processing Record 27 of Set 6 | thompson
# Processing Record 28 of Set 6 | shingu
# Processing Record 29 of Set 6 | richards bay
# Processing Record 30 of Set 6 | linhares
# Processing Record 31 of Set 6 | xunchang
# Processing Record 32 of Set 6 | carai
# Processing Record 33 of Set 6 | susanville
# Processing Record 34 of Set 6 | mankachar
# Processing Record 35 of Set 6 | hof
# Processing Record 36 of Set 6 | nishihara
# Processing Record 37 of Set 6 | haines junction
# Processing Record 38 of Set 6 | lakhipur
# Processing Record 39 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 6 | bandarbeyla
# Processing Record 41 of Set 6 | college
# Processing Record 42 of Set 6 | carutapera
# Processing Record 43 of Set 6 | jequitinhonha
# Processing Record 44 of Set 6 | dauriya
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | karoi
# Processing Record 47 of Set 6 | diffa
# Processing Record 48 of Set 6 | palmer
# Processing Record 49 of Set 6 | methoni
# Processing Record 50 of Set 6 | vestmannaeyjar
# Processing Record 1 of Set 7 | fortuna
# Processing Record 2 of Set 7 | kasongo
# Processing Record 3 of Set 7 | nome
# Processing Record 4 of Set 7 | mahajanga
# Processing Record 5 of Set 7 | touros
# Processing Record 6 of Set 7 | shagonar
# Processing Record 7 of Set 7 | xinzhou
# Processing Record 8 of Set 7 | kollam
# Processing Record 9 of Set 7 | egvekinot
# Processing Record 10 of Set 7 | lake city
# Processing Record 11 of Set 7 | komsomolskiy
# Processing Record 12 of Set 7 | kavali
# Processing Record 13 of Set 7 | waipawa
# Processing Record 14 of Set 7 | caravelas
# Processing Record 15 of Set 7 | takoradi
# Processing Record 16 of Set 7 | qianguo
# Processing Record 17 of Set 7 | jurm
# Processing Record 18 of Set 7 | alice springs
# Processing Record 19 of Set 7 | bridlington
# Processing Record 20 of Set 7 | techiman
# Processing Record 21 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 7 | auki
# Processing Record 23 of Set 7 | edd
# Processing Record 24 of Set 7 | okhotsk
# Processing Record 25 of Set 7 | kisangani
# Processing Record 26 of Set 7 | ruteng
# Processing Record 27 of Set 7 | ucar
# Processing Record 28 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 7 | carmo do rio verde
# Processing Record 30 of Set 7 | renfrew
# Processing Record 31 of Set 7 | vostok
# Processing Record 32 of Set 7 | port augusta
# Processing Record 33 of Set 7 | vardo
# Processing Record 34 of Set 7 | obidos
# Processing Record 35 of Set 7 | sao paulo de olivenca
# Processing Record 36 of Set 7 | trairi
# Processing Record 37 of Set 7 | dudinka
# Processing Record 38 of Set 7 | borzya
# Processing Record 39 of Set 7 | kearney
# Processing Record 40 of Set 7 | ajaccio
# Processing Record 41 of Set 7 | boddam
# Processing Record 42 of Set 7 | cherskiy
# Processing Record 43 of Set 7 | kiama
# Processing Record 44 of Set 7 | namibe
# Processing Record 45 of Set 7 | dabakala
# Processing Record 46 of Set 7 | tanabe
# Processing Record 47 of Set 7 | aswan
# Processing Record 48 of Set 7 | presidente epitacio
# Processing Record 49 of Set 7 | loubomo
# Processing Record 50 of Set 7 | aklavik
# Processing Record 1 of Set 8 | palu
# Processing Record 2 of Set 8 | faanui
# Processing Record 3 of Set 8 | nisia floresta
# Processing Record 4 of Set 8 | maceio
# Processing Record 5 of Set 8 | bayangol
# Processing Record 6 of Set 8 | salmo
# Processing Record 7 of Set 8 | sooke
# Processing Record 8 of Set 8 | khatanga
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | srednekolymsk
# Processing Record 11 of Set 8 | pringsewu
# Processing Record 12 of Set 8 | poronaysk
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | betioky
# Processing Record 15 of Set 8 | talara
# Processing Record 16 of Set 8 | gamba
# Processing Record 17 of Set 8 | marystown
# Processing Record 18 of Set 8 | abu dhabi
# Processing Record 19 of Set 8 | ritchie
# Processing Record 20 of Set 8 | belen
# Processing Record 21 of Set 8 | popondetta
# Processing Record 22 of Set 8 | muchkapskiy
# Processing Record 23 of Set 8 | piopio
# Processing Record 24 of Set 8 | nacala
# Processing Record 25 of Set 8 | paraopeba
# Processing Record 26 of Set 8 | yeppoon
# Processing Record 27 of Set 8 | omboue
# Processing Record 28 of Set 8 | bacolod
# Processing Record 29 of Set 8 | hualmay
# Processing Record 30 of Set 8 | lebu
# Processing Record 31 of Set 8 | anshan
# Processing Record 32 of Set 8 | eureka
# Processing Record 33 of Set 8 | aksarka
# Processing Record 34 of Set 8 | sioux lookout
# Processing Record 35 of Set 8 | southbridge
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | talangnan
# Processing Record 38 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 8 | general elizardo aquino
# Processing Record 40 of Set 8 | molochnoye
# Processing Record 41 of Set 8 | muli
# Processing Record 42 of Set 8 | flin flon
# Processing Record 43 of Set 8 | krasnyy yar
# Processing Record 44 of Set 8 | callaway
# Processing Record 45 of Set 8 | evensk
# Processing Record 46 of Set 8 | katsuura
# Processing Record 47 of Set 8 | voh
# Processing Record 48 of Set 8 | chimore
# Processing Record 49 of Set 8 | bartow
# Processing Record 50 of Set 8 | ahuimanu
# Processing Record 1 of Set 9 | doda
# Processing Record 2 of Set 9 | tigil
# Processing Record 3 of Set 9 | cedartown
# Processing Record 4 of Set 9 | rocha
# Processing Record 5 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 9 | santo antonio da platina
# Processing Record 7 of Set 9 | novoagansk
# Processing Record 8 of Set 9 | lavras
# Processing Record 9 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 9 | ereymentau
# Processing Record 11 of Set 9 | hambantota
# Processing Record 12 of Set 9 | le port
# Processing Record 13 of Set 9 | saint-ambroise
# Processing Record 14 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 9 | serenje
# Processing Record 16 of Set 9 | krasnoselkup
# Processing Record 17 of Set 9 | sao felix do xingu
# Processing Record 18 of Set 9 | lasa
# Processing Record 19 of Set 9 | leningradskiy
# Processing Record 20 of Set 9 | cap malheureux
# Processing Record 21 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | oranjemund
# Processing Record 23 of Set 9 | saint-augustin
# Processing Record 24 of Set 9 | daytona beach
# Processing Record 25 of Set 9 | tara
# Processing Record 26 of Set 9 | talcahuano
# Processing Record 27 of Set 9 | luena
# Processing Record 28 of Set 9 | vila
# Processing Record 29 of Set 9 | kieta
# Processing Record 30 of Set 9 | mariental
# Processing Record 31 of Set 9 | pueblo
# Processing Record 32 of Set 9 | jelgava
# Processing Record 33 of Set 9 | enterprise
# Processing Record 34 of Set 9 | sao filipe
# Processing Record 35 of Set 9 | ilhabela
# Processing Record 36 of Set 9 | port blair
# Processing Record 37 of Set 9 | keti bandar
# Processing Record 38 of Set 9 | batagay-alyta
# Processing Record 39 of Set 9 | inhambane
# Processing Record 40 of Set 9 | san patricio
# Processing Record 41 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 9 | te anau
# Processing Record 44 of Set 9 | zverinogolovskoye
# Processing Record 45 of Set 9 | la ronge
# Processing Record 46 of Set 9 | ulladulla
# Processing Record 47 of Set 9 | lavrentiya
# Processing Record 48 of Set 9 | san cosme y damian
# Processing Record 49 of Set 9 | madinat sittah uktubar
# Processing Record 50 of Set 9 | marsh harbour
# Processing Record 1 of Set 10 | rumoi
# Processing Record 2 of Set 10 | osorno
# Processing Record 3 of Set 10 | barra do corda
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | wad madani
# Processing Record 6 of Set 10 | hirtshals
# Processing Record 7 of Set 10 | berlevag
# Processing Record 8 of Set 10 | san cristobal
# Processing Record 9 of Set 10 | avera
# Processing Record 10 of Set 10 | lorengau
# Processing Record 11 of Set 10 | udarnyy
# Processing Record 12 of Set 10 | damietta
# Processing Record 13 of Set 10 | comodoro rivadavia
# Processing Record 14 of Set 10 | oga
# Processing Record 15 of Set 10 | kushmurun
# Processing Record 16 of Set 10 | pangnirtung
# Processing Record 17 of Set 10 | nsanje
# Processing Record 18 of Set 10 | cidreira
# Processing Record 19 of Set 10 | gelemso
# Processing Record 20 of Set 10 | shunyi
# Processing Record 21 of Set 10 | tobolsk
# Processing Record 22 of Set 10 | stromness
# Processing Record 23 of Set 10 | yarada
# Processing Record 24 of Set 10 | ambanja
# Processing Record 25 of Set 10 | reftinskiy
# Processing Record 26 of Set 10 | crotone
# Processing Record 27 of Set 10 | peace river
# Processing Record 28 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 29 of Set 10 | ajdabiya
# Processing Record 30 of Set 10 | port said
# Processing Record 31 of Set 10 | barauna
# Processing Record 32 of Set 10 | nagua
# Processing Record 33 of Set 10 | radford
# Processing Record 34 of Set 10 | zhongshan
# Processing Record 35 of Set 10 | bjerkvik
# Processing Record 36 of Set 10 | kruisfontein
# Processing Record 37 of Set 10 | trofors
# Processing Record 38 of Set 10 | esperance
# Processing Record 39 of Set 10 | castro marim
# Processing Record 40 of Set 10 | bemidji
# Processing Record 41 of Set 10 | el cobre
# Processing Record 42 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 10 | manadhoo
# Processing Record 44 of Set 10 | maragogi
# Processing Record 45 of Set 10 | black river
# Processing Record 46 of Set 10 | saint-paul
# Processing Record 47 of Set 10 | filadelfia
# Processing Record 48 of Set 10 | nouakchott
# Processing Record 49 of Set 10 | saint-francois
# Processing Record 50 of Set 10 | nanakuli
# Processing Record 1 of Set 11 | freeport
# Processing Record 2 of Set 11 | indian head
# Processing Record 3 of Set 11 | atakpame
# Processing Record 4 of Set 11 | makakilo city
# Processing Record 5 of Set 11 | turukhansk
# Processing Record 6 of Set 11 | bonthe
# Processing Record 7 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 11 | disna
# Processing Record 10 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 11 of Set 11 | helong
# Processing Record 12 of Set 11 | tromso
# Processing Record 13 of Set 11 | christchurch
# Processing Record 14 of Set 11 | bengkulu
# Processing Record 15 of Set 11 | borodino
# Processing Record 16 of Set 11 | oistins
# Processing Record 17 of Set 11 | agua verde
# Processing Record 18 of Set 11 | vanavara
# Processing Record 19 of Set 11 | adrar
# Processing Record 20 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 21 of Set 11 | moindou
# Processing Record 22 of Set 11 | ormara
# Processing Record 23 of Set 11 | boromlya
# Processing Record 24 of Set 11 | antipolo
# Processing Record 25 of Set 11 | noumea
# Processing Record 26 of Set 11 | kumluca
# Processing Record 27 of Set 11 | waitati
# Processing Record 28 of Set 11 | pangai
# Processing Record 29 of Set 11 | parfenyevo
# Processing Record 30 of Set 11 | el alto
# Processing Record 31 of Set 11 | fomboni
# Processing Record 32 of Set 11 | kavaratti
# Processing Record 33 of Set 11 | talnakh
# Processing Record 34 of Set 11 | swellendam
# Processing Record 35 of Set 11 | valparaiso
# Processing Record 36 of Set 11 | iquitos
# Processing Record 37 of Set 11 | norman wells
# Processing Record 38 of Set 11 | misratah
# Processing Record 39 of Set 11 | dingle
# Processing Record 40 of Set 11 | mount isa
# Processing Record 41 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 42 of Set 11 | surgut
# Processing Record 43 of Set 11 | artvin
# Processing Record 44 of Set 11 | ranot
# Processing Record 45 of Set 11 | mitu
# Processing Record 46 of Set 11 | balaguer
# Processing Record 47 of Set 11 | honningsvag
# Processing Record 48 of Set 11 | ravar
# Processing Record 49 of Set 11 | caconda
# Processing Record 50 of Set 11 | fukue
# Processing Record 1 of Set 12 | seredka
# Processing Record 2 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 3 of Set 12 | flinders
# Processing Record 4 of Set 12 | kendari
# Processing Record 5 of Set 12 | belaya gora
# Processing Record 6 of Set 12 | moerai
# Processing Record 7 of Set 12 | rio gallegos
# Processing Record 8 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 12 | beruwala
# Processing Record 10 of Set 12 | lisakovsk
# Processing Record 11 of Set 12 | skjervoy
# Processing Record 12 of Set 12 | luau
# Processing Record 13 of Set 12 | powell
# Processing Record 14 of Set 12 | marica
# Processing Record 15 of Set 12 | aras
# Processing Record 16 of Set 12 | deputatskiy
# Processing Record 17 of Set 12 | yarmouth
# Processing Record 18 of Set 12 | binga
# Processing Record 19 of Set 12 | north platte
# Processing Record 20 of Set 12 | tagusao
# Processing Record 21 of Set 12 | vrangel
# Processing Record 22 of Set 12 | padang
# Processing Record 23 of Set 12 | chardara
# Processing Record 24 of Set 12 | ust-koksa
# Processing Record 25 of Set 12 | rochegda
# Processing Record 26 of Set 12 | harper
# Processing Record 27 of Set 12 | burica
# City not found. Skipping...
# Processing Record 28 of Set 12 | mpika
# Processing Record 29 of Set 12 | high level
# Processing Record 30 of Set 12 | puerto baquerizo moreno
# Processing Record 31 of Set 12 | grants
# Processing Record 32 of Set 12 | kribi
# Processing Record 33 of Set 12 | tulsipur
# Processing Record 34 of Set 12 | opuwo
# Processing Record 35 of Set 12 | kanniyakumari
# Processing Record 36 of Set 12 | la rioja
# Processing Record 37 of Set 12 | angoram
# Processing Record 38 of Set 12 | wanlaweyn
# Processing Record 39 of Set 12 | uchiza
# Processing Record 40 of Set 12 | yenagoa
# Processing Record 41 of Set 12 | sitamarhi
# Processing Record 42 of Set 12 | la asuncion
# Processing Record 43 of Set 12 | novaya igirma
# Processing Record 44 of Set 12 | tinyahuarco
# Processing Record 45 of Set 12 | shitanjing
# Processing Record 46 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 47 of Set 12 | san jose
# Processing Record 48 of Set 12 | newtownards
# Processing Record 49 of Set 12 | aguimes
# Processing Record 50 of Set 12 | isangel
# Processing Record 1 of Set 13 | moron
# Processing Record 2 of Set 13 | yumen
# Processing Record 3 of Set 13 | belyy yar
# Processing Record 4 of Set 13 | kushima
# Processing Record 5 of Set 13 | bubaque
# Processing Record 6 of Set 13 | pitsunda
# Processing Record 7 of Set 13 | manga
# Processing Record 8 of Set 13 | lagos de moreno
# Processing Record 9 of Set 13 | celestun
# Processing Record 10 of Set 13 | north bend
# Processing Record 11 of Set 13 | belogorsk
# Processing Record 12 of Set 13 | shizunai
# Processing Record 13 of Set 13 | susangerd
# Processing Record 14 of Set 13 | sid
# Processing Record 15 of Set 13 | henties bay
# Processing Record 16 of Set 13 | mehamn
# Processing Record 17 of Set 13 | ibra
# Processing Record 18 of Set 13 | posadas
# Processing Record 19 of Set 13 | ambagarh chauki
# Processing Record 20 of Set 13 | abalak
# Processing Record 21 of Set 13 | pimenteiras
# Processing Record 22 of Set 13 | beyneu
# Processing Record 23 of Set 13 | havre-saint-pierre
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Jamestown  42.0970  -79.2353     73.29        46           1
# 1               Magadan  59.5667  150.8000     52.92        97         100
# 2           New Norfolk -42.7826  147.0587     50.92        71         100
# 3              Tasiilaq  65.6145  -37.6368     44.76        97         100
# 4                  Sola -13.8833  167.5500     80.73        75          15
# 5            Chokurdakh  70.6333  147.9167     44.44        64           2
# 6               Gilbues  -9.8317  -45.3439     82.96        28           0
# 7  Vila Franca Do Campo  37.7167  -25.4333     70.21        76          73
# 8               Mataura -46.1927  168.8643     39.47        95          13
# 9         Mount Gambier -37.8333  140.7667     42.71        93          90
#
#    Wind Speed Country                 Date
# 0        8.05      US  2021-07-22 20:41:52
# 1        2.80      RU  2021-07-22 20:46:44
# 2        3.40      AU  2021-07-22 20:45:44
# 3        6.87      GL  2021-07-22 20:46:45
# 4       14.58      VU  2021-07-22 20:46:45
# 5        7.38      RU  2021-07-22 20:46:45
# 6        7.61      BR  2021-07-22 20:46:46
# 7        6.24      PT  2021-07-22 20:46:46
# 8        3.09      NZ  2021-07-22 20:46:47
# 9        6.91      AU  2021-07-22 20:46:47

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.

def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
