# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
from citipy import citipy
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lats_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | el alto
# Processing Record 2 of Set 1 | lompoc
# Processing Record 3 of Set 1 | plettenberg bay
# Processing Record 4 of Set 1 | narsaq
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | kailua
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | yuksekova
# Processing Record 9 of Set 1 | lafiagi
# Processing Record 10 of Set 1 | presidente olegario
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | mount isa
# Processing Record 14 of Set 1 | fort walton beach
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | katangli
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | kavieng
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 1 | ponta delgada
# Processing Record 30 of Set 1 | valparaiso
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | vardo
# Processing Record 33 of Set 1 | saint-denis
# Processing Record 34 of Set 1 | namwala
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | soyo
# Processing Record 41 of Set 1 | varadero
# Processing Record 42 of Set 1 | sao joao da barra
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | tagusao
# Processing Record 45 of Set 1 | kununurra
# Processing Record 46 of Set 1 | sabang
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | cabo san lucas
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | alenquer
# Processing Record 3 of Set 2 | wewak
# Processing Record 4 of Set 2 | sechura
# Processing Record 5 of Set 2 | bilma
# Processing Record 6 of Set 2 | lorengau
# Processing Record 7 of Set 2 | lumeje
# Processing Record 8 of Set 2 | kautokeino
# Processing Record 9 of Set 2 | havre-saint-pierre
# Processing Record 10 of Set 2 | mezen
# Processing Record 11 of Set 2 | the valley
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | calbiga
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | caravelas
# Processing Record 17 of Set 2 | dali
# Processing Record 18 of Set 2 | masallatah
# Processing Record 19 of Set 2 | locharbriggs
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | maldonado
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | ulaanbaatar
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | lancaster
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 2 | mitzic
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | isangel
# Processing Record 33 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 34 of Set 2 | kibondo
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | gigmoto
# Processing Record 41 of Set 2 | ahipara
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | trelew
# Processing Record 44 of Set 2 | constitucion
# Processing Record 45 of Set 2 | caconda
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | klaksvik
# Processing Record 48 of Set 2 | havre
# Processing Record 49 of Set 2 | kenai
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | calama
# Processing Record 3 of Set 3 | novomichurinsk
# Processing Record 4 of Set 3 | coroico
# Processing Record 5 of Set 3 | lityn
# Processing Record 6 of Set 3 | mecca
# Processing Record 7 of Set 3 | panzhihua
# Processing Record 8 of Set 3 | porto novo
# Processing Record 9 of Set 3 | madawaska
# Processing Record 10 of Set 3 | mount gambier
# Processing Record 11 of Set 3 | lucea
# Processing Record 12 of Set 3 | victoria
# Processing Record 13 of Set 3 | souillac
# Processing Record 14 of Set 3 | daru
# Processing Record 15 of Set 3 | abatskoye
# Processing Record 16 of Set 3 | zaysan
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | fuyu
# Processing Record 19 of Set 3 | tiznit
# Processing Record 20 of Set 3 | rabo de peixe
# Processing Record 21 of Set 3 | amarante do maranhao
# Processing Record 22 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 3 | osa
# Processing Record 24 of Set 3 | bukachacha
# Processing Record 25 of Set 3 | chekhov
# Processing Record 26 of Set 3 | nabire
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | monrovia
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | salo
# Processing Record 31 of Set 3 | lagoa
# Processing Record 32 of Set 3 | montrose
# Processing Record 33 of Set 3 | fortuna
# Processing Record 34 of Set 3 | russell
# Processing Record 35 of Set 3 | grand baie
# Processing Record 36 of Set 3 | mataura
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | beatrice
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 41 of Set 3 | bayeux
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | butaritari
# Processing Record 44 of Set 3 | fairbanks
# Processing Record 45 of Set 3 | mae hong son
# Processing Record 46 of Set 3 | saulkrasti
# Processing Record 47 of Set 3 | nemuro
# Processing Record 48 of Set 3 | ayagoz
# Processing Record 49 of Set 3 | novouzensk
# Processing Record 50 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 4 | kirkwall
# Processing Record 2 of Set 4 | sovetskiy
# Processing Record 3 of Set 4 | poum
# Processing Record 4 of Set 4 | gbarnga
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | egvekinot
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | bambous virieux
# Processing Record 9 of Set 4 | balkanabat
# Processing Record 10 of Set 4 | comodoro rivadavia
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | vaini
# Processing Record 13 of Set 4 | maple creek
# Processing Record 14 of Set 4 | luderitz
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | shimoda
# Processing Record 18 of Set 4 | kanigoro
# Processing Record 19 of Set 4 | kruisfontein
# Processing Record 20 of Set 4 | qinzhou
# Processing Record 21 of Set 4 | atambua
# Processing Record 22 of Set 4 | kathu
# Processing Record 23 of Set 4 | ngunguru
# Processing Record 24 of Set 4 | orsha
# Processing Record 25 of Set 4 | floro
# Processing Record 26 of Set 4 | monterey
# Processing Record 27 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 4 | korgen
# Processing Record 29 of Set 4 | labytnangi
# Processing Record 30 of Set 4 | dakar
# Processing Record 31 of Set 4 | sogne
# Processing Record 32 of Set 4 | lima
# Processing Record 33 of Set 4 | parrita
# Processing Record 34 of Set 4 | aklavik
# Processing Record 35 of Set 4 | riyadh
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | aban
# Processing Record 38 of Set 4 | pangkalanbuun
# Processing Record 39 of Set 4 | salinas
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | tautira
# Processing Record 42 of Set 4 | somerset
# Processing Record 43 of Set 4 | susanville
# Processing Record 44 of Set 4 | miandrivazo
# Processing Record 45 of Set 4 | neveklov
# Processing Record 46 of Set 4 | ocos
# Processing Record 47 of Set 4 | la asuncion
# Processing Record 48 of Set 4 | ballina
# Processing Record 49 of Set 4 | vila velha
# Processing Record 50 of Set 4 | cockburn town
# Processing Record 1 of Set 5 | ujjain
# Processing Record 2 of Set 5 | macau
# Processing Record 3 of Set 5 | bathsheba
# Processing Record 4 of Set 5 | dilan
# Processing Record 5 of Set 5 | fort nelson
# Processing Record 6 of Set 5 | lavrentiya
# Processing Record 7 of Set 5 | sao filipe
# Processing Record 8 of Set 5 | san quintin
# Processing Record 9 of Set 5 | castanos
# Processing Record 10 of Set 5 | krasnokamensk
# Processing Record 11 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 5 | pangnirtung
# Processing Record 13 of Set 5 | izhmorskiy
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 5 | ler
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | salym
# Processing Record 19 of Set 5 | humaita
# Processing Record 20 of Set 5 | balakhta
# Processing Record 21 of Set 5 | siderno
# Processing Record 22 of Set 5 | alofi
# Processing Record 23 of Set 5 | saquena
# Processing Record 24 of Set 5 | haines junction
# Processing Record 25 of Set 5 | pirojpur
# Processing Record 26 of Set 5 | katiola
# Processing Record 27 of Set 5 | padang
# Processing Record 28 of Set 5 | mahon
# Processing Record 29 of Set 5 | airai
# Processing Record 30 of Set 5 | rocha
# Processing Record 31 of Set 5 | hobart
# Processing Record 32 of Set 5 | kamaishi
# Processing Record 33 of Set 5 | yokadouma
# Processing Record 34 of Set 5 | los llanos de aridane
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | touros
# Processing Record 37 of Set 5 | port augusta
# Processing Record 38 of Set 5 | istok
# Processing Record 39 of Set 5 | lappeenranta
# Processing Record 40 of Set 5 | ewa beach
# Processing Record 41 of Set 5 | illapel
# Processing Record 42 of Set 5 | bonito
# Processing Record 43 of Set 5 | chokurdakh
# Processing Record 44 of Set 5 | yulara
# Processing Record 45 of Set 5 | norman wells
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | avarua
# Processing Record 48 of Set 5 | pafos
# Processing Record 49 of Set 5 | bac lieu
# Processing Record 50 of Set 5 | saint-leu
# Processing Record 1 of Set 6 | gladstone
# Processing Record 2 of Set 6 | faya
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | baruun-urt
# Processing Record 5 of Set 6 | wilmington
# Processing Record 6 of Set 6 | tonj
# Processing Record 7 of Set 6 | komarikhinskiy
# Processing Record 8 of Set 6 | richards bay
# Processing Record 9 of Set 6 | banmo
# City not found. Skipping...
# Processing Record 10 of Set 6 | kirensk
# Processing Record 11 of Set 6 | kaffrine
# Processing Record 12 of Set 6 | margate
# Processing Record 13 of Set 6 | esil
# Processing Record 14 of Set 6 | izhma
# Processing Record 15 of Set 6 | clyde river
# Processing Record 16 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 6 | erenhot
# Processing Record 18 of Set 6 | iqaluit
# Processing Record 19 of Set 6 | tabuk
# Processing Record 20 of Set 6 | mawlaik
# Processing Record 21 of Set 6 | torbay
# Processing Record 22 of Set 6 | upernavik
# Processing Record 23 of Set 6 | riohacha
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | paamiut
# Processing Record 26 of Set 6 | kalakamati
# Processing Record 27 of Set 6 | penzance
# Processing Record 28 of Set 6 | bengkulu
# Processing Record 29 of Set 6 | hirara
# Processing Record 30 of Set 6 | pisco
# Processing Record 31 of Set 6 | brae
# Processing Record 32 of Set 6 | narayangarh
# Processing Record 33 of Set 6 | xining
# Processing Record 34 of Set 6 | goderich
# Processing Record 35 of Set 6 | barreiras
# Processing Record 36 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 37 of Set 6 | yerbogachen
# Processing Record 38 of Set 6 | leon
# Processing Record 39 of Set 6 | marsh harbour
# Processing Record 40 of Set 6 | viru
# Processing Record 41 of Set 6 | dingle
# Processing Record 42 of Set 6 | okhotsk
# Processing Record 43 of Set 6 | maunabo
# Processing Record 44 of Set 6 | plouzane
# Processing Record 45 of Set 6 | upata
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | saint-joseph
# Processing Record 48 of Set 6 | malinovskiy
# Processing Record 49 of Set 6 | bereda
# Processing Record 50 of Set 6 | vanimo
# Processing Record 1 of Set 7 | banda aceh
# Processing Record 2 of Set 7 | ola
# Processing Record 3 of Set 7 | amos
# Processing Record 4 of Set 7 | ambon
# Processing Record 5 of Set 7 | timra
# Processing Record 6 of Set 7 | eenhana
# Processing Record 7 of Set 7 | kurayoshi
# Processing Record 8 of Set 7 | agaro
# Processing Record 9 of Set 7 | muroto
# Processing Record 10 of Set 7 | shache
# Processing Record 11 of Set 7 | nome
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | mathbaria
# Processing Record 14 of Set 7 | ankang
# Processing Record 15 of Set 7 | chuy
# Processing Record 16 of Set 7 | povenets
# Processing Record 17 of Set 7 | ario
# City not found. Skipping...
# Processing Record 18 of Set 7 | fethiye
# Processing Record 19 of Set 7 | almeirim
# Processing Record 20 of Set 7 | mehamn
# Processing Record 21 of Set 7 | gejiu
# Processing Record 22 of Set 7 | masunga
# Processing Record 23 of Set 7 | labuan
# Processing Record 24 of Set 7 | longyearbyen
# Processing Record 25 of Set 7 | sile
# Processing Record 26 of Set 7 | hamilton
# Processing Record 27 of Set 7 | mountain home
# Processing Record 28 of Set 7 | bikaner
# Processing Record 29 of Set 7 | buala
# Processing Record 30 of Set 7 | fare
# Processing Record 31 of Set 7 | kavaratti
# Processing Record 32 of Set 7 | wamba
# Processing Record 33 of Set 7 | poya
# Processing Record 34 of Set 7 | spoleto
# Processing Record 35 of Set 7 | saint-georges
# Processing Record 36 of Set 7 | sorland
# Processing Record 37 of Set 7 | darhan
# Processing Record 38 of Set 7 | aswan
# Processing Record 39 of Set 7 | vestmannaeyjar
# Processing Record 40 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 41 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 7 | takoradi
# Processing Record 43 of Set 7 | frontera
# Processing Record 44 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 7 | puerto madero
# Processing Record 46 of Set 7 | farafangana
# Processing Record 47 of Set 7 | srednekolymsk
# Processing Record 48 of Set 7 | samarai
# Processing Record 49 of Set 7 | mhlume
# Processing Record 50 of Set 7 | ryotsu
# Processing Record 1 of Set 8 | la ronge
# Processing Record 2 of Set 8 | matcha
# Processing Record 3 of Set 8 | chardara
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | nouadhibou
# Processing Record 6 of Set 8 | ajdabiya
# Processing Record 7 of Set 8 | saint-augustin
# Processing Record 8 of Set 8 | stornoway
# Processing Record 9 of Set 8 | pishin
# Processing Record 10 of Set 8 | salalah
# Processing Record 11 of Set 8 | ilulissat
# Processing Record 12 of Set 8 | gardez
# Processing Record 13 of Set 8 | abonnema
# Processing Record 14 of Set 8 | guerrero negro
# Processing Record 15 of Set 8 | mumford
# Processing Record 16 of Set 8 | jumla
# Processing Record 17 of Set 8 | saltillo
# Processing Record 18 of Set 8 | svetlogorsk
# Processing Record 19 of Set 8 | sinnamary
# Processing Record 20 of Set 8 | vao
# Processing Record 21 of Set 8 | chibuto
# Processing Record 22 of Set 8 | cabedelo
# Processing Record 23 of Set 8 | voyinka
# Processing Record 24 of Set 8 | shitanjing
# Processing Record 25 of Set 8 | lensk
# Processing Record 26 of Set 8 | mandalgovi
# Processing Record 27 of Set 8 | tambura
# Processing Record 28 of Set 8 | leh
# Processing Record 29 of Set 8 | kupang
# Processing Record 30 of Set 8 | clarence town
# Processing Record 31 of Set 8 | hithadhoo
# Processing Record 32 of Set 8 | eirunepe
# Processing Record 33 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 8 | tirupati
# Processing Record 35 of Set 8 | gat
# Processing Record 36 of Set 8 | deputatskiy
# Processing Record 37 of Set 8 | priekule
# Processing Record 38 of Set 8 | bayir
# Processing Record 39 of Set 8 | rawson
# Processing Record 40 of Set 8 | port hedland
# Processing Record 41 of Set 8 | inuvik
# Processing Record 42 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | carballo
# Processing Record 45 of Set 8 | bom sucesso
# Processing Record 46 of Set 8 | kaeo
# Processing Record 47 of Set 8 | hovd
# Processing Record 48 of Set 8 | north platte
# Processing Record 49 of Set 8 | koumac
# Processing Record 50 of Set 8 | ransang
# Processing Record 1 of Set 9 | namibe
# Processing Record 2 of Set 9 | acari
# Processing Record 3 of Set 9 | zabaykalsk
# Processing Record 4 of Set 9 | udachnyy
# Processing Record 5 of Set 9 | ilebo
# Processing Record 6 of Set 9 | umm lajj
# Processing Record 7 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 9 | talcahuano
# Processing Record 9 of Set 9 | almunecar
# Processing Record 10 of Set 9 | banjar
# Processing Record 11 of Set 9 | hof
# Processing Record 12 of Set 9 | haimen
# Processing Record 13 of Set 9 | adrar
# Processing Record 14 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 9 | kahului
# Processing Record 16 of Set 9 | neuquen
# Processing Record 17 of Set 9 | skibbereen
# Processing Record 18 of Set 9 | chumikan
# Processing Record 19 of Set 9 | yura
# Processing Record 20 of Set 9 | gisborne
# Processing Record 21 of Set 9 | alyangula
# Processing Record 22 of Set 9 | selenginsk
# Processing Record 23 of Set 9 | srikakulam
# Processing Record 24 of Set 9 | seoul
# Processing Record 25 of Set 9 | dabakala
# Processing Record 26 of Set 9 | honiara
# Processing Record 27 of Set 9 | phanom sarakham
# Processing Record 28 of Set 9 | dunedin
# Processing Record 29 of Set 9 | aykhal
# Processing Record 30 of Set 9 | liuzhou
# Processing Record 31 of Set 9 | luba
# Processing Record 32 of Set 9 | broken hill
# Processing Record 33 of Set 9 | saint-pacome
# City not found. Skipping...
# Processing Record 34 of Set 9 | gravdal
# Processing Record 35 of Set 9 | takaka
# Processing Record 36 of Set 9 | banikoara
# Processing Record 37 of Set 9 | strelka
# Processing Record 38 of Set 9 | juneau
# Processing Record 39 of Set 9 | mlonggo
# Processing Record 40 of Set 9 | jaru
# Processing Record 41 of Set 9 | benito juarez
# Processing Record 42 of Set 9 | alpena
# Processing Record 43 of Set 9 | madimba
# Processing Record 44 of Set 9 | leningradskiy
# Processing Record 45 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 9 | aden
# Processing Record 47 of Set 9 | skaerbaek
# Processing Record 48 of Set 9 | nanortalik
# Processing Record 49 of Set 9 | sao mateus
# Processing Record 50 of Set 9 | chapais
# Processing Record 1 of Set 10 | gawler
# Processing Record 2 of Set 10 | hauterive
# Processing Record 3 of Set 10 | hun
# Processing Record 4 of Set 10 | itaituba
# Processing Record 5 of Set 10 | najran
# Processing Record 6 of Set 10 | arlit
# Processing Record 7 of Set 10 | lasa
# Processing Record 8 of Set 10 | ilo
# Processing Record 9 of Set 10 | vila franca do campo
# Processing Record 10 of Set 10 | ulaangom
# Processing Record 11 of Set 10 | yaan
# Processing Record 12 of Set 10 | trinidad
# Processing Record 13 of Set 10 | erzin
# Processing Record 14 of Set 10 | matagalpa
# Processing Record 15 of Set 10 | samagaltay
# Processing Record 16 of Set 10 | praia
# Processing Record 17 of Set 10 | teguldet
# Processing Record 18 of Set 10 | malm
# Processing Record 19 of Set 10 | pavlovskiy
# Processing Record 20 of Set 10 | maamba
# Processing Record 21 of Set 10 | husavik
# Processing Record 22 of Set 10 | cayenne
# Processing Record 23 of Set 10 | port stanley
# Processing Record 24 of Set 10 | flinders
# Processing Record 25 of Set 10 | langsa
# Processing Record 26 of Set 10 | olafsvik
# Processing Record 27 of Set 10 | hailun
# Processing Record 28 of Set 10 | aksarka
# Processing Record 29 of Set 10 | ferme-neuve
# Processing Record 30 of Set 10 | amapa
# Processing Record 31 of Set 10 | falkoping
# City not found. Skipping...
# Processing Record 32 of Set 10 | coahuayana
# Processing Record 33 of Set 10 | beterou
# Processing Record 34 of Set 10 | goedereede
# Processing Record 35 of Set 10 | ust-maya
# Processing Record 36 of Set 10 | blackwater
# Processing Record 37 of Set 10 | nhulunbuy
# Processing Record 38 of Set 10 | san patricio
# Processing Record 39 of Set 10 | shingu
# Processing Record 40 of Set 10 | grand gaube
# Processing Record 41 of Set 10 | san jose
# Processing Record 42 of Set 10 | young
# Processing Record 43 of Set 10 | toba
# Processing Record 44 of Set 10 | inhambane
# Processing Record 45 of Set 10 | pitkyaranta
# Processing Record 46 of Set 10 | bara
# Processing Record 47 of Set 10 | bambanglipuro
# Processing Record 48 of Set 10 | alta floresta
# Processing Record 49 of Set 10 | kabalo
# Processing Record 50 of Set 10 | tenenkou
# Processing Record 1 of Set 11 | tommot
# Processing Record 2 of Set 11 | verkhoyansk
# Processing Record 3 of Set 11 | zhigansk
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | asau
# Processing Record 6 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 7 of Set 11 | caxito
# Processing Record 8 of Set 11 | weiser
# Processing Record 9 of Set 11 | meulaboh
# Processing Record 10 of Set 11 | portland
# Processing Record 11 of Set 11 | genhe
# Processing Record 12 of Set 11 | icod de los vinos
# Processing Record 13 of Set 11 | pochutla
# Processing Record 14 of Set 11 | buraydah
# Processing Record 15 of Set 11 | pipraich
# Processing Record 16 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 11 | rustenburg
# Processing Record 18 of Set 11 | huarmey
# Processing Record 19 of Set 11 | okato
# Processing Record 20 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 11 | puerto narino
# Processing Record 22 of Set 11 | makakilo city
# Processing Record 23 of Set 11 | gilbues
# Processing Record 24 of Set 11 | monywa
# Processing Record 25 of Set 11 | san rafael
# Processing Record 26 of Set 11 | sur
# Processing Record 27 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 11 | colares
# Processing Record 29 of Set 11 | owando
# Processing Record 30 of Set 11 | narrabri
# Processing Record 31 of Set 11 | nong chik
# Processing Record 32 of Set 11 | dzaoudzi
# Processing Record 33 of Set 11 | tateyama
# Processing Record 34 of Set 11 | huilong
# Processing Record 35 of Set 11 | port lincoln
# Processing Record 36 of Set 11 | ucluelet
# Processing Record 37 of Set 11 | santa isabel do rio negro
# Processing Record 38 of Set 11 | watsa
# Processing Record 39 of Set 11 | vallenar
# Processing Record 40 of Set 11 | dawei
# Processing Record 41 of Set 11 | japura
# Processing Record 42 of Set 11 | sioux lookout
# Processing Record 43 of Set 11 | morondava
# Processing Record 44 of Set 11 | beira
# Processing Record 45 of Set 11 | oranjemund
# Processing Record 46 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 47 of Set 11 | marsa matruh
# Processing Record 48 of Set 11 | marzuq
# Processing Record 49 of Set 11 | pacific grove
# Processing Record 50 of Set 11 | busca
# Processing Record 1 of Set 12 | slave lake
# Processing Record 2 of Set 12 | salina
# Processing Record 3 of Set 12 | elat
# Processing Record 4 of Set 12 | pringsewu
# Processing Record 5 of Set 12 | celestun
# Processing Record 6 of Set 12 | sawakin
# Processing Record 7 of Set 12 | tazmalt
# Processing Record 8 of Set 12 | biscarrosse
# Processing Record 9 of Set 12 | rapid city
# Processing Record 10 of Set 12 | bocas del toro
# Processing Record 11 of Set 12 | koslan
# Processing Record 12 of Set 12 | achit
# Processing Record 13 of Set 12 | komsomolskiy
# Processing Record 14 of Set 12 | vryburg
# Processing Record 15 of Set 12 | heihe
# Processing Record 16 of Set 12 | kasamwa
# Processing Record 17 of Set 12 | sola
# Processing Record 18 of Set 12 | mingguang
# Processing Record 19 of Set 12 | nuuk
# Processing Record 20 of Set 12 | gimli
# Processing Record 21 of Set 12 | sarangani
# Processing Record 22 of Set 12 | koungou
# Processing Record 23 of Set 12 | sherbakul
# Processing Record 24 of Set 12 | coihaique
# Processing Record 25 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 26 of Set 12 | neiafu
# Processing Record 27 of Set 12 | northam
# Processing Record 28 of Set 12 | nakasongola
# Processing Record 29 of Set 12 | santa rosa
# Processing Record 30 of Set 12 | jibuti
# Processing Record 31 of Set 12 | mega
# Processing Record 32 of Set 12 | bonavista
# Processing Record 33 of Set 12 | aripuana
# Processing Record 34 of Set 12 | port hardy
# Processing Record 35 of Set 12 | tawzar
# City not found. Skipping...
# Processing Record 36 of Set 12 | alice springs
# Processing Record 37 of Set 12 | sistranda
# Processing Record 38 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 12 | orange cove
# Processing Record 40 of Set 12 | whyalla
# Processing Record 41 of Set 12 | sabha
# Processing Record 42 of Set 12 | bela
# Processing Record 43 of Set 12 | kodinsk
# Processing Record 44 of Set 12 | dumka
# Processing Record 45 of Set 12 | kuusamo
# Processing Record 46 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 12 | sisimiut
# Processing Record 48 of Set 12 | manzhouli
# Processing Record 49 of Set 12 | murray bridge
# Processing Record 50 of Set 12 | perevolotskiy
# Processing Record 1 of Set 13 | tigil
# Processing Record 2 of Set 13 | waddan
# Processing Record 3 of Set 13 | darlowo
# Processing Record 4 of Set 13 | robertsport
# Processing Record 5 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 13 | ust-omchug
# Processing Record 7 of Set 13 | mayo
# Processing Record 8 of Set 13 | tromso
# Processing Record 9 of Set 13 | ramnagar
# Processing Record 10 of Set 13 | pandan
# Processing Record 11 of Set 13 | esperance
# Processing Record 12 of Set 13 | victoria point
# Processing Record 13 of Set 13 | birjand
# Processing Record 14 of Set 13 | gander
# Processing Record 15 of Set 13 | poopo
# Processing Record 16 of Set 13 | codrington
# Processing Record 17 of Set 13 | jiangyou
# Processing Record 18 of Set 13 | clermont
# Processing Record 19 of Set 13 | vysotsk
# Processing Record 20 of Set 13 | dickinson
# Processing Record 21 of Set 13 | tual
# Processing Record 22 of Set 13 | baykit
# Processing Record 23 of Set 13 | jimma
# Processing Record 24 of Set 13 | khandagayty
# Processing Record 25 of Set 13 | tighina
# Processing Record 26 of Set 13 | gboko
# Processing Record 27 of Set 13 | beloha
# Processing Record 28 of Set 13 | ossora
# Processing Record 29 of Set 13 | monster
# Processing Record 30 of Set 13 | evanston
# Processing Record 31 of Set 13 | mwene-ditu
# Processing Record 32 of Set 13 | beitbridge
# Processing Record 33 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 13 | moju
# Processing Record 35 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 13 | loandjili
# Processing Record 37 of Set 13 | suntar
# Processing Record 38 of Set 13 | kerrville
# Processing Record 39 of Set 13 | berlevag
# Processing Record 40 of Set 13 | ust-kuyga
# Processing Record 41 of Set 13 | fort dodge
# Processing Record 42 of Set 13 | porto seguro
# Processing Record 43 of Set 13 | ornes
# Processing Record 44 of Set 13 | bocanda
# Processing Record 45 of Set 13 | boyolangu
# Processing Record 46 of Set 13 | la rioja
# Processing Record 47 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 13 | conceicao do araguaia
# Processing Record 50 of Set 13 | necochea
# Processing Record 1 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 14 | avera
# Processing Record 3 of Set 14 | waitati
# Processing Record 4 of Set 14 | natal
# Processing Record 5 of Set 14 | san cristobal
# Processing Record 6 of Set 14 | tuatapere
# Processing Record 7 of Set 14 | sokoto
# Processing Record 8 of Set 14 | andenes
# Processing Record 9 of Set 14 | nanfeng
# Processing Record 10 of Set 14 | kyabe
# Processing Record 11 of Set 14 | pangody
# Processing Record 12 of Set 14 | bondo
# Processing Record 13 of Set 14 | puruliya
# Processing Record 14 of Set 14 | benguela
# Processing Record 15 of Set 14 | buin
# Processing Record 16 of Set 14 | smolenka
# Processing Record 17 of Set 14 | tarko-sale
# Processing Record 18 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 19 of Set 14 | kingman
# Processing Record 20 of Set 14 | pozo colorado
# Processing Record 21 of Set 14 | itoman
# Processing Record 22 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 23 of Set 14 | lemesos
# City not found. Skipping...
# Processing Record 24 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 14 | villa corzo
# Processing Record 26 of Set 14 | tura
# Processing Record 27 of Set 14 | bubaque
# Processing Record 28 of Set 14 | bahia honda
# Processing Record 29 of Set 14 | galway
# Processing Record 30 of Set 14 | verkhnyaya inta
# Processing Record 31 of Set 14 | tsiroanomandidy
# Processing Record 32 of Set 14 | klamath falls
# Processing Record 33 of Set 14 | tutoia
# Processing Record 34 of Set 14 | namatanai
# Processing Record 35 of Set 14 | iracoubo
# Processing Record 36 of Set 14 | homer
# Processing Record 37 of Set 14 | acajutla
# Processing Record 38 of Set 14 | gold coast
# Processing Record 39 of Set 14 | taoudenni
# Processing Record 40 of Set 14 | aguadilla
# Processing Record 41 of Set 14 | mancio lima
# Processing Record 42 of Set 14 | ahwa
# Processing Record 43 of Set 14 | crab hill
# City not found. Skipping...
# Processing Record 44 of Set 14 | nortelandia
# Processing Record 45 of Set 14 | fukue
# Processing Record 46 of Set 14 | bungu
# Processing Record 47 of Set 14 | srivardhan
# Processing Record 48 of Set 14 | biak
# Processing Record 49 of Set 14 | kondinskoye
# Processing Record 50 of Set 14 | sobolevo
# Processing Record 1 of Set 15 | maniitsoq
# Processing Record 2 of Set 15 | tazovskiy
# Processing Record 3 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 15 | maun
# Processing Record 5 of Set 15 | marinilla
# Processing Record 6 of Set 15 | carutapera
# Processing Record 7 of Set 15 | nautla
# Processing Record 8 of Set 15 | gao
# Processing Record 9 of Set 15 | akyab
# Processing Record 10 of Set 15 | mackay
# Processing Record 11 of Set 15 | isakly
# Processing Record 12 of Set 15 | valsamata
# Processing Record 13 of Set 15 | taksimo
# Processing Record 14 of Set 15 | ust-tsilma
# Processing Record 15 of Set 15 | tupiza
# Processing Record 16 of Set 15 | helmsdale
# Processing Record 17 of Set 15 | dunda
# Processing Record 18 of Set 15 | progreso
# Processing Record 19 of Set 15 | ferkessedougou
# Processing Record 20 of Set 15 | panaba
# Processing Record 21 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 15 | darnah
# Processing Record 23 of Set 15 | kilakarai
# Processing Record 24 of Set 15 | igunga
# Processing Record 25 of Set 15 | vysokogornyy
# Processing Record 26 of Set 15 | grants pass
# Processing Record 27 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 28 of Set 15 | mosquera
# Processing Record 29 of Set 15 | kawalu
# Processing Record 30 of Set 15 | gizo
# Processing Record 31 of Set 15 | umea
# Processing Record 32 of Set 15 | tabou
# Processing Record 33 of Set 15 | west bay
# Processing Record 34 of Set 15 | betul
# Processing Record 35 of Set 15 | takahagi
# Processing Record 36 of Set 15 | sale
# Processing Record 37 of Set 15 | anderson
# Processing Record 38 of Set 15 | henties bay
# Processing Record 39 of Set 15 | yenagoa
# Processing Record 40 of Set 15 | kot putli
# City not found. Skipping...
# Processing Record 41 of Set 15 | lusambo
# Processing Record 42 of Set 15 | obihiro
# Processing Record 43 of Set 15 | pedernales
# Processing Record 44 of Set 15 | iquique
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              El Alto  -4.2714  -81.2147     63.91        84          42
# 1               Lompoc  34.6391 -120.4579     72.21        79          90
# 2      Plettenberg Bay -34.0527   23.3716     48.54        83         100
# 3               Narsaq  60.9167  -46.0500     46.62        95         100
# 4          New Norfolk -42.7826  147.0587     57.88        40          30
# 5               Kailua  21.4022 -157.7394     85.98        65          20
# 6           Bredasdorp -34.5322   20.0403     45.57        79         100
# 7            Yuksekova  37.5736   44.2872     59.47        48           0
# 8              Lafiagi   8.8667    5.4167     74.75        85         100
# 9  Presidente Olegario -18.4178  -46.4181     55.18        54          77
#
#    Wind Speed Country                 Date Current Description
# 0       16.62      PE  2021-07-23 02:02:31    scattered clouds
# 1       10.36      US  2021-07-23 02:06:37     overcast clouds
# 2        3.94      ZA  2021-07-23 02:06:38          light rain
# 3        5.84      GL  2021-07-23 02:06:38     overcast clouds
# 4        6.93      AU  2021-07-23 02:06:38    scattered clouds
# 5       17.27      US  2021-07-23 02:06:39          few clouds
# 6        3.31      ZA  2021-07-23 02:06:04     overcast clouds
# 7        2.35      TR  2021-07-23 02:06:39           clear sky
# 8        3.96      NG  2021-07-23 02:06:40     overcast clouds
# 9        4.36      BR  2021-07-23 02:06:40       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
